# %% [markdown]
# Taken from this tutorial http://www.datacarpentry.org/python-ecology-lesson/04-merging-data
# https://github.com/fedhere/UInotebooks
# https://github.com/fedhere/PUI2016_fb55
# https://github.com/dlk253/PUI2016_dlk253
# https://github.com/jontoy/PUI2016_jt2276

# %%
import pandas as pd
surveys_df = pd.read_csv("https://ndownloader.figshare.com/files/2292172",
                         keep_default_na=False, na_values=[""])
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
species_df = pd.read_csv('https://ndownloader.figshare.com/files/3299483',
                         keep_default_na=False, na_values=[""])
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
# read in first 10 lines of surveys table
survey_sub = surveys_df.head(10)
survey_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# grab the last 10 rows (minus the last one)
survey_sub_last10 = surveys_df[-11:-1]
survey_sub_last10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
#
#        weight
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# ...

# %%
#reset the index values to the second dataframe appends properly
survey_sub_last10=survey_sub_last10.reset_index(drop=True)

# %%
survey_sub_last10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35539     12   31  2002       15         SF    M             26.0
# 1      35540     12   31  2002       15         PB    F             26.0
# 2      35541     12   31  2002       15         PB    F             24.0
# 3      35542     12   31  2002       15         PB    F             26.0
# 4      35543     12   31  2002       15         PB    F             27.0
# 5      35544     12   31  2002       15         US  NaN              NaN
# 6      35545     12   31  2002       15         AH  NaN              NaN
# 7      35546     12   31  2002       15         AH  NaN              NaN
# 8      35547     12   31  2002       10         RM    F             15.0
# 9      35548     12   31  2002        7         DO    M             36.0
#
#    weight
# 0    68.0
# 1    23.0
# 2    31.0
# 3    29.0
# 4    34.0
# 5     NaN
# 6     NaN
# 7     NaN
# 8    14.0
# 9    51.0

# %%
# stack the DataFrames on top of each other
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35539     12   31  2002       15         SF    M             26.0
# 1      35540     12   31  2002       15         PB    F             26.0
# ...

# %%
# stack the DataFrames on top of each other and reset the index
vertical_stack=vertical_stack.reset_index(drop=True)
vertical_stack
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35539     12   31  2002       15         SF    M             26.0
# 11      35540     12   31  2002       15         PB    F             26.0
# ...

# %%
# stack the DataFrames side by side
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)
horizontal_stack = horizontal_stack.reset_index(drop=True)
horizontal_stack
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight  record_id  month  day  year  plot_id species_id  sex  \
# 0     NaN      35539     12   31  2002       15         SF    M
# ...

# %%
import os

# %%
#testing that the PUIDATA enviornmental variable exists
test = os.getenv("PUIDATA") 
print(test)
# Out:
# /home/cusp/dlk253/PUIdata

# %%
# Write DataFrame to CSV which will be output to the PUIdata directoy on compute /home/cusp/dlk253/PUIdata
vertical_stack.to_csv(os.getenv("PUIDATA") + "/" + "out.csv")

# %%
 # for testing purposes I am going to read the output back into python and make sure it all looks good
newOutput = pd.read_csv(os.getenv("PUIDATA") + "/" + "out.csv", keep_default_na=False, na_values=[""])
newOutput
# Out:
#     Unnamed: 0  record_id  month  day  year  plot_id species_id  sex  \
# 0            0          1      7   16  1977        2         NL    M
# 1            1          2      7   16  1977        3         NL    M
# 2            2          3      7   16  1977        2         DM    F
# 3            3          4      7   16  1977        7         DM    M
# 4            4          5      7   16  1977        3         DM    M
# 5            5          6      7   16  1977        1         PF    M
# 6            6          7      7   16  1977        2         PE    F
# 7            7          8      7   16  1977        1         DM    M
# 8            8          9      7   16  1977        1         DM    F
# 9            9         10      7   16  1977        6         PF    F
# 10          10      35539     12   31  2002       15         SF    M
# 11          11      35540     12   31  2002       15         PB    F
# 12          12      35541     12   31  2002       15         PB    F
# ...

# %%
surveys_df = pd.read_csv("https://raw.githubusercontent.com/datacarpentry/archive-datacarpentry/master/data/biology/species.csv",
                         keep_default_na=False, na_values=[""])
surveys_df
# Out:
#    species_id             genus          species                   taxa
# 0          AB        Amphispiza        bilineata                   Bird
# 1          AH  Ammospermophilus          harrisi    Rodent-not censused
# 2          AS        Ammodramus       savannarum                   Bird
# 3          BA           Baiomys          taylori                 Rodent
# 4          CB   Campylorhynchus  brunneicapillus                   Bird
# 5          CM       Calamospiza      melanocorys                   Bird
# 6          CQ        Callipepla         squamata                   Bird
# 7          CS          Crotalus       scutalatus                Reptile
# 8          CT     Cnemidophorus           tigris                Reptile
# 9          CU     Cnemidophorus        uniparens                Reptile
# 10         CV          Crotalus          viridis                Reptile
# 11         DM         Dipodomys         merriami                 Rodent
# ...

# %%
#from the data carpentry archive: https://github.com/datacarpentry/archive-datacarpentry
surveys_df = pd.read_csv("https://raw.githubusercontent.com/datacarpentry/archive-datacarpentry/master/data/biology/surveys.csv",
                         keep_default_na=False, na_values=[""])

species_df = pd.read_csv("https://raw.githubusercontent.com/datacarpentry/archive-datacarpentry/master/data/biology/species.csv",
                         keep_default_na=False, na_values=[""])

# %% [markdown]
# ## When we concatenated our DataFrames we simply added them to each other - stacking them either vertically or side by side. Another way to combine DataFrames is to use columns in each dataset that contain common values (a common unique id). Combining DataFrames using a common field is called "joining".

# %%
# read in first 10 lines of surveys table
survey_sub = surveys_df.head(40)

# %%
species_sub = species_df.head(40)

# %%
species_sub.columns
species_sub
# Out:
#    species_id             genus          species                 taxa
# 0          AB        Amphispiza        bilineata                 Bird
# 1          AH  Ammospermophilus          harrisi  Rodent-not censused
# 2          AS        Ammodramus       savannarum                 Bird
# 3          BA           Baiomys          taylori               Rodent
# 4          CB   Campylorhynchus  brunneicapillus                 Bird
# 5          CM       Calamospiza      melanocorys                 Bird
# 6          CQ        Callipepla         squamata                 Bird
# 7          CS          Crotalus       scutalatus              Reptile
# 8          CT     Cnemidophorus           tigris              Reptile
# 9          CU     Cnemidophorus        uniparens              Reptile
# 10         CV          Crotalus          viridis              Reptile
# 11         DM         Dipodomys         merriami               Rodent
# ...

# %%
survey_sub.columns
survey_sub
# Out:
#     record_id  month  day  year  plot species  sex  wgt
# 0           1      7   16  1977     2      NL    M  NaN
# 1           2      7   16  1977     3      NL    M  NaN
# 2           3      7   16  1977     2      DM    F  NaN
# 3           4      7   16  1977     7      DM    M  NaN
# 4           5      7   16  1977     3      DM    M  NaN
# 5           6      7   16  1977     1      PF    M  NaN
# 6           7      7   16  1977     2      PE    F  NaN
# 7           8      7   16  1977     1      DM    M  NaN
# 8           9      7   16  1977     1      DM    F  NaN
# 9          10      7   16  1977     6      PF    F  NaN
# 10         11      7   16  1977     5      DS    F  NaN
# 11         12      7   16  1977     7      DM    M  NaN
# 12         13      7   16  1977     3      DM    M  NaN
# 13         14      7   16  1977     8      DM  NaN  NaN
# 14         15      7   16  1977     6      DM    F  NaN
# 15         16      7   16  1977     4      DM    F  NaN
# ...

# %% [markdown]
# ## have to rename the record_id column form the survey sub data, in order for the next part of the code to work.

# %%
old_names = [u'record_id', u'month', u'day', u'year', u'plot', u'species', u'sex',
       u'wgt'] 
new_names = [u'record_id', u'month', u'day', u'year', u'plot', u'species_id', u'sex',
       u'wgt']
survey_sub.rename(columns=dict(zip(old_names, new_names)), inplace=True)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/frame.py:2754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
survey_sub.columns
survey_sub
# Out:
#     record_id  month  day  year  plot species_id  sex  wgt
# 0           1      7   16  1977     2         NL    M  NaN
# 1           2      7   16  1977     3         NL    M  NaN
# 2           3      7   16  1977     2         DM    F  NaN
# 3           4      7   16  1977     7         DM    M  NaN
# 4           5      7   16  1977     3         DM    M  NaN
# 5           6      7   16  1977     1         PF    M  NaN
# 6           7      7   16  1977     2         PE    F  NaN
# 7           8      7   16  1977     1         DM    M  NaN
# 8           9      7   16  1977     1         DM    F  NaN
# 9          10      7   16  1977     6         PF    F  NaN
# 10         11      7   16  1977     5         DS    F  NaN
# 11         12      7   16  1977     7         DM    M  NaN
# 12         13      7   16  1977     3         DM    M  NaN
# 13         14      7   16  1977     8         DM  NaN  NaN
# 14         15      7   16  1977     6         DM    F  NaN
# ...

# %%
species_sub.columns
species_sub
# Out:
#    species_id             genus          species                 taxa
# 0          AB        Amphispiza        bilineata                 Bird
# 1          AH  Ammospermophilus          harrisi  Rodent-not censused
# 2          AS        Ammodramus       savannarum                 Bird
# 3          BA           Baiomys          taylori               Rodent
# 4          CB   Campylorhynchus  brunneicapillus                 Bird
# 5          CM       Calamospiza      melanocorys                 Bird
# 6          CQ        Callipepla         squamata                 Bird
# 7          CS          Crotalus       scutalatus              Reptile
# 8          CT     Cnemidophorus           tigris              Reptile
# 9          CU     Cnemidophorus        uniparens              Reptile
# 10         CV          Crotalus          viridis              Reptile
# 11         DM         Dipodomys         merriami               Rodent
# ...

# %%
# in this case `species_id` is the only column name in  both dataframes, so if we skippd `left_on`
# and `right_on` arguments we would still get the same result
merged_inner = pd.merge(left=survey_sub,right=species_sub, left_on='species_id', right_on='species_id')
# what's the size of the output data?
merged_inner.shape
merged_inner
# Out:
#     record_id  month  day  year  plot species_id  sex  wgt        genus  \
# 0           1      7   16  1977     2         NL    M  NaN      Neotoma
# 1           2      7   16  1977     3         NL    M  NaN      Neotoma
# 2          22      7   17  1977    15         NL    F  NaN      Neotoma
# 3          38      7   17  1977    17         NL    M  NaN      Neotoma
# 4           3      7   16  1977     2         DM    F  NaN    Dipodomys
# 5           4      7   16  1977     7         DM    M  NaN    Dipodomys
# 6           5      7   16  1977     3         DM    M  NaN    Dipodomys
# 7           8      7   16  1977     1         DM    M  NaN    Dipodomys
# 8           9      7   16  1977     1         DM    F  NaN    Dipodomys
# 9          12      7   16  1977     7         DM    M  NaN    Dipodomys
# 10         13      7   16  1977     3         DM    M  NaN    Dipodomys
# 11         14      7   16  1977     8         DM  NaN  NaN    Dipodomys
# ...

# %% [markdown]
# #The result of an inner join of survey_sub and species_sub is a new DataFrame that contains the combined set of columns from survey_sub and species_sub. It only contains rows that have two-letter species codes that are the same in both the survey_sub and species_sub DataFrames. In other words, if a row in survey_sub has a value of species_id that does not appear in the species_id column of species, it will not be included in the DataFrame returned by an inner join. Similarly, if a row in species_sub has a value of species_id that does not appear in the species_id column of survey_sub, that row will not be included in the DataFrame returned by an inner join.
#
# The two DataFrames that we want to join are passed to the merge function using the left and right argument. The left_on='species' argument tells merge to use the species_id column as the join key from survey_sub (the left DataFrame). Similarly , the right_on='species_id' argument tells merge to use the species_id column as the join key from species_sub (the right DataFrame). For inner joins, the order of the left and right arguments does not matter.
#
# The result merged_inner DataFrame contains all of the columns from survey_sub (record id, month, day, etc.) as well as all the columns from species_sub (species_id, genus, species, and taxa).
#
# Notice that merged_inner has fewer rows than survey_sub. This is an indication that there were rows in surveys_df with value(s) for species_id that do not exist as value(s) for species_id in species_df.
# more details on this here: http://www.datacarpentry.org/python-ecology-lesson/04-merging-data

# %%
merged_left = pd.merge(left=survey_sub,right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_left
# Out:
#     record_id  month  day  year  plot species_id  sex  wgt        genus  \
# 0           1      7   16  1977     2         NL    M  NaN      Neotoma
# 1           2      7   16  1977     3         NL    M  NaN      Neotoma
# 2           3      7   16  1977     2         DM    F  NaN    Dipodomys
# 3           4      7   16  1977     7         DM    M  NaN    Dipodomys
# 4           5      7   16  1977     3         DM    M  NaN    Dipodomys
# 5           6      7   16  1977     1         PF    M  NaN  Perognathus
# 6           7      7   16  1977     2         PE    F  NaN   Peromyscus
# 7           8      7   16  1977     1         DM    M  NaN    Dipodomys
# 8           9      7   16  1977     1         DM    F  NaN    Dipodomys
# 9          10      7   16  1977     6         PF    F  NaN  Perognathus
# 10         11      7   16  1977     5         DS    F  NaN    Dipodomys
# 11         12      7   16  1977     7         DM    M  NaN    Dipodomys
# ...

# %%
surveys_df.columns
surveys_df
# Out:
#        record_id  month  day  year  plot species  sex   wgt
# 0              1      7   16  1977     2      NL    M   NaN
# 1              2      7   16  1977     3      NL    M   NaN
# 2              3      7   16  1977     2      DM    F   NaN
# 3              4      7   16  1977     7      DM    M   NaN
# 4              5      7   16  1977     3      DM    M   NaN
# 5              6      7   16  1977     1      PF    M   NaN
# 6              7      7   16  1977     2      PE    F   NaN
# 7              8      7   16  1977     1      DM    M   NaN
# 8              9      7   16  1977     1      DM    F   NaN
# 9             10      7   16  1977     6      PF    F   NaN
# 10            11      7   16  1977     5      DS    F   NaN
# 11            12      7   16  1977     7      DM    M   NaN
# 12            13      7   16  1977     3      DM    M   NaN
# 13            14      7   16  1977     8      DM  NaN   NaN
# 14            15      7   16  1977     6      DM    F   NaN
# ...

# %% [markdown]
# Create a new DataFrame by joining the contents of the surveys.csv and species.csv tables. Then calculate and plot the distribution of:
#
# 1.taxa by plot
#
# 2.taxa by sex by plot

# %%
species_df.columns
# Out:
# Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')

# %%
surveys_df.columns
# Out:
# Index([u'record_id', u'month', u'day', u'year', u'plot', u'species', u'sex',
#        u'wgt'],
#       dtype='object')

# %%
old_names = [u'record_id', u'month', u'day', u'year', u'plot', u'species', u'sex',
       u'wgt'] 
new_names = [u'record_id', u'month', u'day', u'year', u'plot', u'species_id', u'sex',
       u'wgt']
surveys_df.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %%
surveys_df.columns
# Out:
# Index([u'record_id', u'month', u'day', u'year', u'plot', u'species_id', u'sex',
#        u'wgt'],
#       dtype='object')

# %%
merged_inner_species = pd.merge(left=surveys_df,right=species_df, left_on='species_id', right_on='species_id')
# what's the size of the output data?
merged_inner_species.shape
merged_inner_species.head(20)
merged_inner_species.size
# Out:
# 382646

# %%
merged_inner_species
# Out:
#        record_id  month  day  year  plot species_id  sex   wgt          genus  \
# 0              1      7   16  1977     2         NL    M   NaN        Neotoma
# 1              2      7   16  1977     3         NL    M   NaN        Neotoma
# 2             22      7   17  1977    15         NL    F   NaN        Neotoma
# 3             38      7   17  1977    17         NL    M   NaN        Neotoma
# 4             72      8   19  1977     2         NL    M   NaN        Neotoma
# 5            106      8   20  1977    12         NL  NaN   NaN        Neotoma
# 6            107      8   20  1977    18         NL  NaN   NaN        Neotoma
# 7            121      8   21  1977    15         NL  NaN   NaN        Neotoma
# 8            171      9   11  1977    12         NL  NaN   NaN        Neotoma
# 9            194      9   12  1977    11         NL  NaN   NaN        Neotoma
# 10           214      9   12  1977    17         NL  NaN   NaN        Neotoma
# ...

# %%
#looking at the different data types to figure out what would be interesting to plot.
#getting all the types of taxa 
merged_inner_species.taxa.unique()
# Out:
# array(['Rodent', 'Rodent-not censused', 'Rabbit', 'Bird', 'Reptile'], dtype=object)

# %%
#getting all the genus
merged_inner_species.genus.unique()
# Out:
# array(['Neotoma', 'Dipodomys', 'Perognathus', 'Peromyscus', 'Chaetodipus',
#        'Sigmodon', 'Onychomys', 'Spermophilus', 'Reithrodontomys',
#        'Sylvilagus', 'Ammospermophilus', 'Amphispiza', 'Campylorhynchus',
#        'Calamospiza', 'Callipepla', 'Pipilo', 'Pooecetes', 'Crotalus',
#        'Rodent', 'Zonotrichia', 'Lizard', 'Sceloporus', 'Baiomys',
#        'Ammodramus', 'Cnemidophorus', 'Sparrow'], dtype=object)

# %%
#getting all the species_id
merged_inner_species.species_id.unique()
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ', 'RF',
#        'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS', 'SC',
#        'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX', 'PB',
#        'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
#getting all the year
merged_inner_species.year.unique()
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002])

# %%
#getting all the species
merged_inner_species.species.unique()
# Out:
# array(['albigula', 'merriami', 'flavus', 'eremicus', 'spectabilis',
#        'penicillatus', 'hispidus', 'torridus', 'ordii', 'sp.', 'spilosoma',
#        'leucogaster', 'megalotis', 'audubonii', 'maniculatus', 'harrisi',
#        'bilineata', 'brunneicapillus', 'melanocorys', 'squamata',
#        'fulvescens', 'chlorurus', 'gramineus', 'fuscus', 'viridis',
#        'leucophrys', 'scutalatus', 'clarki', 'taylori', 'fulviventer',
#        'montanus', 'savannarum', 'ochrognathus', 'intermedius',
#        'tereticaudus', 'uniparens', 'undulatus', 'baileyi', 'leucopus',
#        'tigris'], dtype=object)

# %%
#import MATPLOTLIB
import matplotlib.pyplot as plt

# %%
small_dataset = merged_inner_species[:50]

# %%
plot_data = small_dataset['plot']

# %%
plt.plot(plot_data, label='My Data')

# %%
#show the plot
plt.show()
#if we want to save the plot 
#plt.savefig('myplot.png')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-2cc18e066360> in <module>()
#       1 #show the plot
# ----> 2 plt.show()
#       3 #if we want to save the plot
#       4 #plt.savefig('myplot.png')
#
# NameError: name 'plt' is not defined

# %%
#put some labels on it
#plot some data https://github.com/datacarpentry/archive-datacarpentry/blob/master/lessons/python/07-plotting-with-matplotlib.md
plt.plot(plot_data,'o', label='My Data', color='m', linewidth=0.5)
#plt.plot(plot_data,'+', label='My Data', color='b', alpha=0.6, linewidth=0.5)
plt.xlim(-10, 15)
plt.xlabel('Index')
plt.ylabel('Plot Value')
plt.title('The Plot Value From surveys.csv')
plt.figure(figsize=(10, 8), dpi=200)
plt.subplots_adjust(left=0.1, bottom=0.2, right=0.99, top=0.99)
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-958e4a1a77bc> in <module>()
#       1 #put some labels on it
#       2 #plot some data https://github.com/datacarpentry/archive-datacarpentry/blob/master/lessons/python/07-plotting-with-matplotlib.md
# ----> 3 plt.plot(plot_data,'o', label='My Data', color='m', linewidth=0.5)
#       4 #plt.plot(plot_data,'+', label='My Data', color='b', alpha=0.6, linewidth=0.5)
#       5 plt.xlim(-10, 15)
#
# NameError: name 'plt' is not defined

# %%
grouped_plot_data = small_dataset.groupby('sex')

# %%
colors = ['r', 'g'] #we'll be cycling through these colors
color_index = 0
for group in grouped_plot_data:
    color = colors[color_index]
    group_label = group[0]
    group_data = group[1]
    plt.plot(group_data['plot'], color=color, label=group_label)
    color_index += 1
plt.legend()
plt.show()
