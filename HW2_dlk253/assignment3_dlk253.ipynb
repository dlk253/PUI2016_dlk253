# %%
from __future__ import division, print_function
__author__ = 'dlk253 CUSP 2016'
import os
import numpy as np
from numpy.random import randn
import pylab as pl
from pandas import Series, DataFrame
import pandas
import pandas as pd

# %%
DFdata = os.getenv('DFDATA')

# %%
fin = open(DFdata + "/uedp-fegm/1414245967/uedp-fegm", "r")
fin.read
fin.close()

# %%
# setting up some preferences
# %pylab inline

np.set_printoptions(precision=4, threshold=500)
np.random.seed(123321)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_location = pd.read_csv(DFdata + "/uedp-fegm/1414245967/uedp-fegm")
#df_student.drop(['Computer Experience', 'Major', '#Students Name'], axis=1, inplace=True)
df_location.drop(df_location.columns[[0,1,4]], axis=1)
# Out:
#        Consumption (therms)    Consumption (GJ)
# 0                    58338.0              6155.0
# 1                   550055.0             58034.0
# 2                   260502.0             27484.0
# 3                      265.0                28.0
# 4                     2076.0               219.0
# 5                    12845.0              1355.0
# 6                   186224.0             19648.0
# 7                    61263.0              6464.0
# 8                   192654.0             20326.0
# 9                   178497.0             18832.0
# 10                  228453.0             24103.0
# 11                  213234.0             22497.0
# 12                  111236.0             11736.0
# 13                   23970.0              2529.0
# 14                   21822.0              2302.0
# 15                  124706.0             13157.0
# 16                  185761.0             19599.0
# 17                  122395.0             12913.0
# ...
